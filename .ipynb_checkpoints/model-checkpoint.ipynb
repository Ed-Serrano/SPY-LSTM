# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import keras_tuner as kt
import matplotlib.pyplot as plt

spy_data = pd.read_csv("spy_max.csv")
spy_data = spy_data.iloc[::-1].reset_index(drop=True)
spy_data = spy_data.drop(columns=['Date'])

scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(spy_data.drop(columns=['Close/Last']))
scaled_labels = scaler.fit_transform(spy_data[['Close/Last']]).flatten()

# %%
def create_sequence(data, labels, seq_length, output_length):
    X = []
    y = []
    for i in range(len(data) - seq_length - output_length + 1):
        X.append(data[i:i + seq_length])
        y.append(labels[i + seq_length:i + seq_length + output_length])
    return np.array(X), np.array(y)

seq_len = 10
output_len = 1  

X, y = create_sequence(scaled_features, scaled_labels, seq_len, output_len)

X = np.reshape(X, (X.shape[0], X.shape[1], X.shape[2]))

def build_model(hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=128, step=32),
                   return_sequences=False,
                   input_shape=(seq_len, X.shape[2])))
    model.add(Dense(units=hp.Int('dense_units', min_value=16, max_value=64, step=16)))
    model.add(Dense(units=output_len))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

tuner = kt.Hyperband(
    build_model,
    objective='val_loss',
    max_epochs=10, 
    directory='keras_tuner_dir',
    project_name='lstm_hyperparameter_tuning'
)
# Out:
# Reloading Tuner from keras_tuner_dir/lstm_hyperparameter_tuning/tuner0.json

# %%
test_size = int(0.2 * len(X))
X_train_full, X_test = X[:-test_size], X[-test_size:]
y_train_full, y_test = y[:-test_size], y[-test_size:]

val_size = int(0.2 * len(X_train_full))
X_train, X_val = X_train_full[:-val_size], X_train_full[-val_size:]
y_train, y_val = y_train_full[:-val_size], y_train_full[-val_size:]

tuner.search(X_train, y_train, epochs=50, 
             validation_data=(X_val, y_val), 
             callbacks=[EarlyStopping(patience=3)])

best_hps = tuner.get_best_hyperparameters()[0]

n_splits = 5
tscv = TimeSeriesSplit(n_splits=n_splits)
rmse_values = []

for fold_index, (train_index, val_index) in enumerate(tscv.split(X_train_full)):
    model = tuner.hypermodel.build(best_hps)
    
    X_train_fold, X_val_fold = X_train_full[train_index], X_train_full[val_index]
    y_train_fold, y_val_fold = y_train_full[train_index], y_train_full[val_index]
    
    model.fit(X_train_fold, y_train_fold, 
              validation_data=(X_val_fold, y_val_fold), 
              epochs=50, 
              callbacks=[EarlyStopping(patience=3)])
    
    val_loss = model.evaluate(X_val_fold, y_val_fold)
    rmse_values.append(np.sqrt(val_loss))  


final_model = tuner.hypermodel.build(best_hps)
final_model.fit(
    X_train_full, 
    y_train_full, 
    epochs=50,
    batch_size=32,
    validation_split=0.2,  
    callbacks=[EarlyStopping(patience=3)]
)

test_loss = final_model.evaluate(X_test, y_test)
test_rmse = np.sqrt(test_loss)
print(test_loss, test_rmse)
# Out:
# Epoch 1/50
# /Users/edserrano/Library/Python/3.9/lib/python/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8671e-04 - val_loss: 3.6319e-04
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1574e-04 - val_loss: 2.7553e-04
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6048e-05 - val_loss: 3.0532e-04
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0138e-05 - val_loss: 1.5698e-04
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9269e-05 - val_loss: 7.6868e-05
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2380e-05 - val_loss: 7.0504e-05
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3259e-05 - val_loss: 6.8946e-05
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5831e-05 - val_loss: 1.1386e-04
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3654e-05 - val_loss: 6.0156e-05
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1247e-05 - val_loss: 6.1124e-05
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3481e-05 - val_loss: 7.0172e-05
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4953e-05 - val_loss: 5.4328e-05
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8185e-05 - val_loss: 9.0775e-05
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0868e-05 - val_loss: 1.3473e-04
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5907e-05 - val_loss: 4.9022e-05
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1820e-05 - val_loss: 8.5804e-05
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0973e-05 - val_loss: 6.0886e-05
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0968e-05 - val_loss: 4.6312e-05
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5091e-05 - val_loss: 8.3070e-05
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9084e-05 - val_loss: 5.0731e-05
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0695e-05 - val_loss: 4.3684e-05
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1152e-05 - val_loss: 1.1936e-04
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7124e-05 - val_loss: 4.6419e-05
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7656e-05 - val_loss: 5.3734e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0066e-05
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - val_loss: 9.7628e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9526e-04 - val_loss: 0.0019
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2742e-04 - val_loss: 8.4033e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8152e-05 - val_loss: 6.4710e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6828e-05 - val_loss: 2.7322e-04
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1429e-05 - val_loss: 8.3568e-05
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7411e-05 - val_loss: 7.2168e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7873e-05 - val_loss: 1.0909e-04
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6228e-05 - val_loss: 7.1573e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0889e-05 - val_loss: 7.5463e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0929e-05 - val_loss: 6.7798e-05
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8274e-05 - val_loss: 6.2388e-05
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6967e-05 - val_loss: 8.6330e-05
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6126e-05 - val_loss: 9.3242e-05
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4914e-05 - val_loss: 7.0696e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0610e-05
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - val_loss: 0.0017
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8422e-04 - val_loss: 1.5267e-04
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1563e-05 - val_loss: 1.2789e-04
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7964e-05 - val_loss: 1.2469e-04
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4400e-05 - val_loss: 1.1594e-04
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9797e-05 - val_loss: 1.1061e-04
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5895e-05 - val_loss: 1.2343e-04
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7701e-05 - val_loss: 1.1716e-04
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6927e-05 - val_loss: 1.1807e-04
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1629e-04
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - val_loss: 4.3694e-04
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1428e-04 - val_loss: 4.0530e-04
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1392e-05 - val_loss: 3.8770e-04
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3542e-05 - val_loss: 3.8324e-04
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9442e-05 - val_loss: 4.2880e-04
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4536e-05 - val_loss: 3.5269e-04
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2825e-05 - val_loss: 3.6008e-04
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2510e-05 - val_loss: 3.5794e-04
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5378e-05 - val_loss: 3.3742e-04
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3029e-05 - val_loss: 3.3503e-04
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9962e-05 - val_loss: 3.3519e-04
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8037e-05 - val_loss: 4.2251e-04
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7759e-05 - val_loss: 3.9515e-04
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8746e-04
# Epoch 1/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0043 - val_loss: 8.6768e-04
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5203e-04 - val_loss: 5.1880e-04
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2616e-04 - val_loss: 5.9727e-04
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3621e-04 - val_loss: 3.8695e-04
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0720e-04 - val_loss: 3.8201e-04
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1244e-04 - val_loss: 3.8223e-04
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1937e-04 - val_loss: 3.6013e-04
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4231e-04 - val_loss: 4.2977e-04
# Epoch 9/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3847e-04 - val_loss: 3.5743e-04
# Epoch 10/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1094e-04 - val_loss: 3.4180e-04
# Epoch 11/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1396e-04 - val_loss: 4.2080e-04
# Epoch 12/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0203e-04 - val_loss: 4.0297e-04
# Epoch 13/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0685e-04 - val_loss: 3.9420e-04
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8480e-04
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0119 - val_loss: 4.5751e-04
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0664e-04 - val_loss: 4.4484e-04
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5055e-04 - val_loss: 4.3216e-04
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3701e-04 - val_loss: 4.2839e-04
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4508e-04 - val_loss: 3.6926e-04
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4375e-04 - val_loss: 4.0028e-04
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2935e-04 - val_loss: 3.8424e-04
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3050e-04 - val_loss: 6.1834e-04
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0437e-04
# 0.0005353561136871576 0.02313776380048767

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title('Predicted vs Actual Prices')
plt.xlabel('Time Steps')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 8))
plt.scatter(y_test_actual, predictions, alpha=0.5)
plt.title('Predicted vs Actual Prices')
plt.xlabel('Under')
plt.ylabel('Over')
plt.grid(True)
plt.show()

residuals = predictions - y_test_actual
plt.figure(figsize=(10, 6))
plt.scatter(y_test_actual, residuals, alpha=0.5)
plt.title('Residuals vs Actual Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Residuals')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(residuals, bins=30, edgecolor='k')
plt.title('Distribution of Prediction Errors')
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
